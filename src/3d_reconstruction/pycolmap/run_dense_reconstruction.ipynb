# %%
# !pip install opencv-python
# !pip install numpy
# !pip install pycolmap-cuda12
# !pip install open3d
# !pip install scipy
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:32a1fb62-ce3a-4bce-bc8f-b894c78661d9

# %%
# !git clone https://github.com/jfraszczak/grasping-data.git

# %%
# !git clone https://github.com/jfraszczak/Robot-Grasping.git

# %%
from google.colab import files
files.download("reconstruction.ply")
