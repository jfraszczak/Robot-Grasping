# %%
# !pip install opencv-python
# !pip install numpy
# !pip install pycolmap-cuda12
# !pip install open3d
# !pip install scipy
# Out:
# ...
#   Using cached pycolmap_cuda12-3.13.0-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (10 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.9.79-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.10.19-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 MB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 125.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.3/68.3 MB 38.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
# ...

# %%
# !git clone https://github.com/jfraszczak/grasping-data.git
# !git clone https://github.com/jfraszczak/Robot-Grasping.git
# %cd Robot-Grasping/
# !git checkout "3d-reconstruction"
# Out:
# Cloning into 'grasping-data'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 75 (delta 6), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (75/75), 196.22 MiB | 23.99 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# Cloning into 'Robot-Grasping'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 46 (delta 14), reused 40 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 5.02 MiB | 37.28 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/Robot-Grasping
# Branch '3d-reconstruction' set up to track remote branch '3d-reconstruction' from 'origin'.
# Switched to a new branch '3d-reconstruction'

# %%
# !python -m src.3d_reconstruction.pycolmap.run_dense_reconstruction --images_path "../grasping-data/cashew-1" --calibration_path "../grasping-data/calibration/*.jpg"
# Out:
# I20260121 20:29:56.057423 133960316220992 misc.cc:44]
# ...
# Feature extraction
# ...
# I20260121 20:29:56.058161 133960021468736 sift.cc:720] Creating SIFT GPU feature extractor
# I20260121 20:29:56.317789 133960013076032 feature_extraction.cc:260] Processed file [1/8]
# I20260121 20:29:56.317826 133960013076032 feature_extraction.cc:263]   Name:            IMG_20251210_100953216.jpg
# I20260121 20:29:56.317830 133960013076032 feature_extraction.cc:272]   Dimensions:      4080 x 2296
# I20260121 20:29:56.317833 133960013076032 feature_extraction.cc:275]   Camera:          #1 - OPENCV
# I20260121 20:29:56.317836 133960013076032 feature_extraction.cc:278]   Focal Length:    2596.72px (Prior)
# I20260121 20:29:56.317844 133960013076032 feature_extraction.cc:282]   Features:        8906 (SIFT)
# I20260121 20:29:56.619799 133960013076032 feature_extraction.cc:293]   GPS:             LAT=52.396, LON=16.949, ALT=0.000
# ...

# %%
from google.colab import files
files.download("reconstruction.ply")
